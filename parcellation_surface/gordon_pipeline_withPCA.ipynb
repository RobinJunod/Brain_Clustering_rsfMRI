# %% [markdown]
# # TODO : create a parcellation from the average of the similatriy matrix,

# %%
from pathlib import Path
import numpy as np
import nibabel as nib 
import networkx as nx

from smoothing import smooth_surface_graph
from gradient import compute_gradients, compute_gradient_average, build_mesh_graph, \
                     save_gradient_mgh, load_gradient_mgh
from watershed import watershed_by_flooding, save_labels_mgh \
                    , load_labels_mgh
from visualization import visualize_brain_surface

# %%
# Path Run all subject lh on run 1

config = {
"fsavg6_dir": Path(r"D:\Data_Conn_Preproc\fsaverage6"),
"subjects_dir": Path(r"D:\Data_Conn_Preproc\PPSFACE_N20")
}

hemisphere = 'lh'
run = 2

surface_path = config["fsavg6_dir"] / "surf" / f"{hemisphere}.white"
surface_inf_path = config["fsavg6_dir"] / "surf" / f"{hemisphere}.inflated"
# Extract the Surface Mesh
coords, faces = nib.freesurfer.read_geometry(str(surface_path))
coords_, faces_ = nib.freesurfer.read_geometry(str(surface_inf_path))
graph = build_mesh_graph(faces)

# Output paths
output_gradient_dir = config["subjects_dir"] / "gradient"
(output_gradient_dir).mkdir(exist_ok=True, parents=True)
output_labels_dir = config["subjects_dir"] / "labels"
(output_labels_dir).mkdir(exist_ok=True, parents=True)



# Variables path
subject = f"{1:02d}"
subj_dir = config["subjects_dir"] / f"sub-{subject}"

# Define paths using pathlib
surf_fmri_path = subj_dir / "func" / f"surf_conn_sub{subject}_run{run}_{hemisphere}.func.fsaverage6.mgh"
vol_fmri_path = subj_dir / "func" / f"niftiDATA_Subject{subject}_Condition000_run{run}.nii.gz"
brain_mask_path = subj_dir / f"sub{subject}_freesurfer" / "mri" / "brainmask.mgz"


# If needed, the grey matter mask
# gm_mask_path = subj_dir / f"sub{subject}_freesurfer" / "mri" / f"{hemisphere}.ribbon.mgz"


print('all paths defined')
# Out:
# all paths defined

# %%
from nilearn.image import resample_img
def load_data_normalized(surf_fmri_path,
                         vol_fmri_path, 
                         brain_mask_path):

    # Load the surface data
    surf_fmri = nib.load(str(surf_fmri_path)).get_fdata().squeeze()
    surf_fmri_n = (surf_fmri - np.mean(surf_fmri, axis=1, keepdims=True)) / np.std(surf_fmri, axis=1, keepdims=True)
    
    # Load the images using nibabel
    vol_fmri = nib.load(str(vol_fmri_path))
    mask_img = nib.load(brain_mask_path)

    # resample the mask to the right one
    mask_img = resample_img(
        mask_img,
        target_affine=vol_fmri.affine,
        target_shape=vol_fmri.get_fdata().shape[:-1],
        interpolation='nearest',
        force_resample=True
    )

    fmri_data = vol_fmri.get_fdata()
    mask_data = mask_img.get_fdata().astype(bool)  # Convert mask to boolean
    # Normalize the data
    vol_fmri = fmri_data[mask_data] 
    vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
    
    # Remove nans from the data
    surf_fmri_n = np.nan_to_num(surf_fmri_n).astype(np.float32)
    vol_fmri_n = np.nan_to_num(vol_fmri_n).astype(np.float32)
    return surf_fmri_n, vol_fmri_n

# %%
from sklearn.decomposition import PCA
def compute_similarty_matrix_PCA(vol_fmri_n,
                                 surf_fmri_n,
                                 n_components=17):
    """Compute the similarity matrix with a PCA dim reduction
    Args:
        vol_fmri_n (_type_): _description_
        surf_fmri_n (_type_): _description_
        n_components (int, optional): _description_. Defaults to 17.
    """
    # 4. Run PCA on the time series data
    n_components = 17  # Number of PCA components you want to extract
    pca = PCA(n_components=n_components)
    temporal_modes = pca.fit_transform(vol_fmri_n.T).astype(np.float32) # shape = (n_timepoints, n_components)
    
    # Correlation formula for normalized data
    corr_matrix = (surf_fmri_n @ temporal_modes)  / (surf_fmri_n.shape[1] - 1) # shape = (n_vertices, n_components)
    # Similarty matrix
    sim_matrix = np.corrcoef(corr_matrix, dtype=np.float32) # shape = (n_vertices, n_vertices)
    sim_matrix = np.nan_to_num(sim_matrix) # remove nans if any
    return sim_matrix

# %%
# Full pipeline my way

# 1 : Compute the average similartiy matrix across each subjects
sim_matrix_sum = np.zeros(nx.adjacency_matrix(graph).shape, dtype=np.float32)
print('sim_matrix_sum shape', sim_matrix_sum.shape)
for i in range(1,21):
    if i == 5:
        continue # Subject 5 is missing
    # Variables path
    subject = f"{i:02d}"
    subj_dir = config["subjects_dir"] / f"sub-{subject}"

    # Define paths using pathlib
    surf_fmri_path = subj_dir / "func" / f"surf_conn_sub{subject}_run{run}_{hemisphere}.func.fsaverage6.mgh"
    vol_fmri_path = subj_dir / "func" / f"niftiDATA_Subject{subject}_Condition000_run{run}.nii.gz"
    brain_mask_path = subj_dir / f"sub{subject}_freesurfer" / "mri" / "brainmask.mgz"

    # Load the data
    surf_fmri_n, vol_fmri_n = load_data_normalized(surf_fmri_path,
                                                    vol_fmri_path, 
                                                    brain_mask_path)
    
    sim_matrix_sum += compute_similarty_matrix_PCA(vol_fmri_n,
                                                   surf_fmri_n)

# Save the similarty matrix
sim_matrix_path = config["subjects_dir"] / f"similarity_matrix_allsub_run{run}_{hemisphere}.npy"
np.save(sim_matrix_path, sim_matrix_sum)
    
    
# 2 : Smooth the similatry matrix
sim_matrix_smoothed = smooth_surface_graph(graph, sim_matrix_sum, iterations=5)

# 3 : Compute the gradient of the similarty matrix
gradients = compute_gradients(graph, sim_matrix_smoothed)
gradients_sum = gradients.sum(axis=1).astype(np.float32)

# 3.1 : Smooth the gradient
gradient_smoothed = smooth_surface_graph(graph, gradients_sum, iterations=10)
gradients_path = config["subjects_dir"] / f"gradients_allsub_run{run}_{hemisphere}.npy"
np.save(gradients_path, gradients)

# 4 : Compute the watershed of each gradients to optain gradient maps
labels = watershed_by_flooding(graph, gradient_smoothed)
labels_path = config["subjects_dir"] / f"labels_allsub_run{run}_{hemisphere}.npy"
np.save(labels_path, labels)

# 5 : Visualize the watershed
visualize_brain_surface(coords_, faces_, gradient_smoothed)

# %%
# Full pipeline GORDON WAY

# 1 : Compute the average similartiy matrix across each subjects
sim_matrix_sum = np.zeros(nx.adjacency_matrix(graph).shape, dtype=np.float32)
print('sim_matrix_sum shape', sim_matrix_sum.shape)
for i in range(1,21):
    if i == 5:
        continue # Subject 5 is missing
    # Variables path
    subject = f"{i:02d}"
    subj_dir = config["subjects_dir"] / f"sub-{subject}"

    # Define paths using pathlib
    surf_fmri_path = subj_dir / "func" / f"surf_conn_sub{subject}_run{run}_{hemisphere}.func.fsaverage6.mgh"
    vol_fmri_path = subj_dir / "func" / f"niftiDATA_Subject{subject}_Condition000_run{run}.nii.gz"
    brain_mask_path = subj_dir / f"sub{subject}_freesurfer" / "mri" / "brainmask.mgz"

    # Load the data
    surf_fmri_n, vol_fmri_n = load_data_normalized(surf_fmri_path,
                                                    vol_fmri_path, 
                                                    brain_mask_path)
    
    sim_matrix_sum += compute_similarty_matrix_PCA(vol_fmri_n,
                                                   surf_fmri_n)

# Save the similarty matrix
sim_matrix_path = config["subjects_dir"] / f"similarity_matrix_allsub_run{run}_{hemisphere}.npy"
np.save(sim_matrix_path, sim_matrix_sum)
    
    
# 2 : Smooth the similatry matrix
sim_matrix_smoothed = smooth_surface_graph(graph, sim_matrix_sum, iterations=5)

# 3 : Compute the gradient of the similarty matrix
gradients = compute_gradients(graph, sim_matrix_smoothed)

# 3.1 : Smooth the gradient
gradients_smoothed = smooth_surface_graph(graph, gradients, iterations=10)
gradients_path = config["subjects_dir"] / f"gradients_smoothed_allsub_run{run}_{hemisphere}.npy"
np.save(gradients_path, gradients)

# 4 : Create the boundary map from the watershed
boundary_map = np.zeros_like(gradients[:,0]).astype(np.float32)
for map_idx in range(gradients.shape[1]): # loop over each columns of the matrix
    if map_idx % 10 == 0:
        print(f"Processing map {map_idx}") # Print the current map index
    boundary = (watershed_by_flooding(graph, gradients_smoothed[:,map_idx])<0)*1 # Extract the bounary from the watershed algorithm
    boundary_map += boundary
boundary_map_path = config["subjects_dir"] / f"boundary_smoothed_map_allsub_run{run}_{hemisphere}.npy"
np.save(boundary_map_path, boundary_map)

# 5 : Visualize the bounardy map
visualize_brain_surface(coords_, faces_, boundary_map)
# Out:
# sim_matrix_sum shape (40962, 40962)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:8: RuntimeWarning: invalid value encountered in divide
#   surf_fmri_n = (surf_fmri - np.mean(surf_fmri, axis=1, keepdims=True)) / np.std(surf_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# c:\Users\Robin\Documents\1_EPFL\pdme\code\brain_parcellation\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# c:\Users\Robin\Documents\1_EPFL\pdme\code\brain_parcellation\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:8: RuntimeWarning: invalid value encountered in divide
#   surf_fmri_n = (surf_fmri - np.mean(surf_fmri, axis=1, keepdims=True)) / np.std(surf_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# c:\Users\Robin\Documents\1_EPFL\pdme\code\brain_parcellation\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# c:\Users\Robin\Documents\1_EPFL\pdme\code\brain_parcellation\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:8: RuntimeWarning: invalid value encountered in divide
#   surf_fmri_n = (surf_fmri - np.mean(surf_fmri, axis=1, keepdims=True)) / np.std(surf_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# c:\Users\Robin\Documents\1_EPFL\pdme\code\brain_parcellation\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# c:\Users\Robin\Documents\1_EPFL\pdme\code\brain_parcellation\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:8: RuntimeWarning: invalid value encountered in divide
#   surf_fmri_n = (surf_fmri - np.mean(surf_fmri, axis=1, keepdims=True)) / np.std(surf_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# c:\Users\Robin\Documents\1_EPFL\pdme\code\brain_parcellation\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# c:\Users\Robin\Documents\1_EPFL\pdme\code\brain_parcellation\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# C:\Users\Robin\AppData\Local\Temp\ipykernel_22416\3368662244.py:27: RuntimeWarning: invalid value encountered in divide
#   vol_fmri_n = (vol_fmri - np.mean(vol_fmri, axis=1, keepdims=True)) / np.std(vol_fmri, axis=1, keepdims=True)
# Processing map 0
# Processing map 10
# Processing map 20
# Processing map 30
# Processing map 40
# Processing map 50
# Processing map 60
# Processing map 70
# Processing map 80
# Processing map 90
# Processing map 100
# Processing map 110
# Processing map 120
# Processing map 130
# Processing map 140
# Processing map 150
# Processing map 160
# Processing map 170
# Processing map 180
# Processing map 190
# Processing map 200
# Processing map 210
# Processing map 220
# Processing map 230
# Processing map 240
# Processing map 250
# Processing map 260
# Processing map 270
# Processing map 280
# Processing map 290
# Processing map 300
# Processing map 310
# Processing map 320
# Processing map 330
# Processing map 340
# Processing map 350
# Processing map 360
# Processing map 370
# Processing map 380
# Processing map 390
# Processing map 400
# Processing map 410
# Processing map 420
# Processing map 430
# Processing map 440
# Processing map 450
# Processing map 460
# Processing map 470
# Processing map 480
# Processing map 490
# Processing map 500
# Processing map 510
# Processing map 520
# Processing map 530
# Processing map 540
# Processing map 550
# Processing map 560
# Processing map 570
# Processing map 580
# Processing map 590
# Processing map 600
# Processing map 610
# Processing map 620
# Processing map 630
# Processing map 640
# Processing map 650
# Processing map 660
# Processing map 670
# Processing map 680
# Processing map 690
# Processing map 700
# Processing map 710
# Processing map 720
# Processing map 730
# Processing map 740
# Processing map 750
# Processing map 760
# Processing map 770
# Processing map 780
# Processing map 790
# Processing map 800
# Processing map 810
# Processing map 820
# Processing map 830
# Processing map 840
# Processing map 850
# Processing map 860
# Processing map 870
# Processing map 880
# Processing map 890
# Processing map 900
# Processing map 910
# Processing map 920
# Processing map 930
# Processing map 940
# Processing map 950
# Processing map 960
# Processing map 970
# Processing map 980
# Processing map 990
# Processing map 1000
# Processing map 1010
# Processing map 1020
# Processing map 1030
# Processing map 1040
# Processing map 1050
# Processing map 1060
# Processing map 1070
# Processing map 1080
# Processing map 1090
# Processing map 1100
# Processing map 1110
# Processing map 1120
# Processing map 1130
# Processing map 1140
# Processing map 1150
# Processing map 1160
# Processing map 1170
# Processing map 1180
# Processing map 1190
# Processing map 1200
# Processing map 1210
# Processing map 1220
# Processing map 1230
# Processing map 1240
# Processing map 1250
# Processing map 1260
# Processing map 1270
# Processing map 1280
# Processing map 1290
# Processing map 1300
# Processing map 1310
# Processing map 1320
# Processing map 1330
# Processing map 1340
# Processing map 1350
# Processing map 1360
# Processing map 1370
# Processing map 1380
# Processing map 1390
# Processing map 1400
# Processing map 1410
# Processing map 1420
# Processing map 1430
# Processing map 1440
# Processing map 1450
# Processing map 1460
# Processing map 1470
# Processing map 1480
# Processing map 1490
# Processing map 1500
# Processing map 1510
# Processing map 1520
# Processing map 1530
# Processing map 1540
# Processing map 1550
# Processing map 1560
# Processing map 1570
# Processing map 1580
# Processing map 1590
# Processing map 1600
# Processing map 1610
# Processing map 1620
# Processing map 1630
# Processing map 1640
# Processing map 1650
# Processing map 1660
# Processing map 1670
# Processing map 1680
# Processing map 1690
# Processing map 1700
# Processing map 1710
# Processing map 1720
# Processing map 1730
# Processing map 1740
# Processing map 1750
# Processing map 1760
# Processing map 1770
# Processing map 1780
# Processing map 1790
# Processing map 1800
# Processing map 1810
# Processing map 1820
# Processing map 1830
# Processing map 1840
# Processing map 1850
# Processing map 1860
# Processing map 1870
# Processing map 1880
# Processing map 1890
# Processing map 1900
# Processing map 1910
# Processing map 1920
# Processing map 1930
# Processing map 1940
# Processing map 1950
# Processing map 1960
# Processing map 1970
# Processing map 1980
# Processing map 1990
# Processing map 2000
# Processing map 2010
# Processing map 2020
# Processing map 2030
# Processing map 2040
# Processing map 2050
# Processing map 2060
# Processing map 2070
# Processing map 2080
# Processing map 2090
# Processing map 2100
# Processing map 2110
# Processing map 2120
# Processing map 2130
# Processing map 2140
# Processing map 2150
# Processing map 2160
# Processing map 2170
# Processing map 2180
# Processing map 2190
# Processing map 2200
# Processing map 2210
# Processing map 2220
# Processing map 2230
# Processing map 2240
# Processing map 2250
# Processing map 2260
# Processing map 2270
# Processing map 2280
# Processing map 2290
# Processing map 2300
# Processing map 2310
# Processing map 2320
# Processing map 2330
# Processing map 2340
# Processing map 2350
# Processing map 2360
# Processing map 2370
# Processing map 2380
# Processing map 2390
# Processing map 2400
# Processing map 2410
# Processing map 2420
# Processing map 2430
# Processing map 2440
# Processing map 2450
# Processing map 2460
# Processing map 2470
# Processing map 2480
# Processing map 2490
# Processing map 2500
# Processing map 2510
# Processing map 2520
# Processing map 2530
# Processing map 2540
# Processing map 2550
# Processing map 2560
# Processing map 2570
# Processing map 2580
# Processing map 2590
# Processing map 2600
# Processing map 2610
# Processing map 2620
# Processing map 2630
# Processing map 2640
# Processing map 2650
# Processing map 2660
# Processing map 2670
# Processing map 2680
# Processing map 2690
# Processing map 2700
# Processing map 2710
# Processing map 2720
# Processing map 2730
# Processing map 2740
# Processing map 2750
# Processing map 2760
# Processing map 2770
# Processing map 2780
# Processing map 2790
# Processing map 2800
# Processing map 2810
# Processing map 2820
# Processing map 2830
# Processing map 2840
# Processing map 2850
# Processing map 2860
# Processing map 2870
# Processing map 2880
# Processing map 2890
# Processing map 2900
# Processing map 2910
# Processing map 2920
# Processing map 2930
# Processing map 2940
# Processing map 2950
# Processing map 2960
# Processing map 2970
# Processing map 2980
# Processing map 2990
# Processing map 3000
# Processing map 3010
# Processing map 3020
# Processing map 3030
# Processing map 3040
# Processing map 3050
# Processing map 3060
# Processing map 3070
# Processing map 3080
# Processing map 3090
# Processing map 3100
# Processing map 3110
# Processing map 3120
# Processing map 3130
# Processing map 3140
# Processing map 3150
# Processing map 3160
# Processing map 3170
# Processing map 3180
# Processing map 3190
# Processing map 3200
# Processing map 3210
# Processing map 3220
# Processing map 3230
# Processing map 3240
# Processing map 3250
# Processing map 3260
# Processing map 3270
# Processing map 3280
# Processing map 3290
# Processing map 3300
# Processing map 3310
# Processing map 3320
# Processing map 3330
# Processing map 3340
# Processing map 3350
# Processing map 3360
# Processing map 3370
# Processing map 3380
# Processing map 3390
# Processing map 3400
# Processing map 3410
# Processing map 3420
# Processing map 3430
# Processing map 3440
# Processing map 3450
# Processing map 3460
# Processing map 3470
# Processing map 3480
# Processing map 3490
# Processing map 3500
# Processing map 3510
# Processing map 3520
# Processing map 3530
# Processing map 3540
# Processing map 3550
# Processing map 3560
# Processing map 3570
# Processing map 3580
# Processing map 3590
# Processing map 3600
# Processing map 3610
# Processing map 3620
# Processing map 3630
# Processing map 3640
# Processing map 3650
# Processing map 3660
# Processing map 3670
# Processing map 3680
# Processing map 3690
# Processing map 3700
# Processing map 3710
# Processing map 3720
# Processing map 3730
# Processing map 3740
# Processing map 3750
# Processing map 3760
# Processing map 3770
# Processing map 3780
# Processing map 3790
# Processing map 3800
# Processing map 3810
# Processing map 3820
# Processing map 3830
# Processing map 3840
# Processing map 3850
# Processing map 3860
# Processing map 3870
# Processing map 3880
# Processing map 3890
# Processing map 3900
# Processing map 3910
# Processing map 3920
# Processing map 3930
# Processing map 3940
# Processing map 3950
# Processing map 3960
# Processing map 3970
# Processing map 3980
# Processing map 3990
# Processing map 4000
# Processing map 4010
# Processing map 4020
# Processing map 4030
# Processing map 4040
# Processing map 4050
# Processing map 4060
# Processing map 4070
# Processing map 4080
# Processing map 4090
# Processing map 4100
# Processing map 4110
# Processing map 4120
# Processing map 4130
# Processing map 4140
# Processing map 4150
# Processing map 4160
# Processing map 4170
# Processing map 4180
# Processing map 4190
# Processing map 4200
# Processing map 4210
# Processing map 4220
# Processing map 4230
# Processing map 4240
# Processing map 4250
# Processing map 4260
# Processing map 4270
# Processing map 4280
# Processing map 4290
# Processing map 4300
# Processing map 4310
# Processing map 4320
# Processing map 4330
# Processing map 4340
# Processing map 4350
# Processing map 4360
# Processing map 4370
# Processing map 4380
# Processing map 4390
# Processing map 4400
# Processing map 4410
# Processing map 4420
# Processing map 4430
# Processing map 4440
# Processing map 4450
# Processing map 4460
# Processing map 4470
# Processing map 4480
# Processing map 4490
# Processing map 4500
# Processing map 4510
# Processing map 4520
# Processing map 4530
# Processing map 4540
# Processing map 4550
# Processing map 4560
# Processing map 4570
# Processing map 4580
# Processing map 4590
# Processing map 4600
# Processing map 4610
# Processing map 4620
# Processing map 4630
# Processing map 4640
# Processing map 4650
# Processing map 4660
# Processing map 4670
# Processing map 4680
# Processing map 4690
# Processing map 4700
# Processing map 4710
# Processing map 4720
# Processing map 4730
# Processing map 4740
# Processing map 4750
# Processing map 4760
# Processing map 4770
# Processing map 4780
# Processing map 4790
# Processing map 4800
# Processing map 4810
# Processing map 4820
# Processing map 4830
# Processing map 4840
# Processing map 4850
# Processing map 4860
# Processing map 4870
# Processing map 4880
# Processing map 4890
# Processing map 4900
# Processing map 4910
# Processing map 4920
# Processing map 4930
# Processing map 4940
# Processing map 4950
# Processing map 4960
# Processing map 4970
# Processing map 4980
# Processing map 4990
# Processing map 5000
# Processing map 5010
# Processing map 5020
# Processing map 5030
# Processing map 5040
# Processing map 5050
# Processing map 5060
# Processing map 5070
# Processing map 5080
# Processing map 5090
# Processing map 5100
# Processing map 5110
# Processing map 5120
# Processing map 5130
# Processing map 5140
# Processing map 5150
# Processing map 5160
# Processing map 5170
# Processing map 5180
# Processing map 5190
# Processing map 5200
# Processing map 5210
# Processing map 5220
# Processing map 5230
# Processing map 5240
# Processing map 5250
# Processing map 5260
# Processing map 5270
# Processing map 5280
# Processing map 5290
# Processing map 5300
# Processing map 5310
# Processing map 5320
# Processing map 5330
# Processing map 5340
# Processing map 5350
# Processing map 5360
# Processing map 5370
# Processing map 5380
# Processing map 5390
# Processing map 5400
# Processing map 5410
# Processing map 5420
# Processing map 5430
# Processing map 5440
# Processing map 5450
# Processing map 5460
# Processing map 5470
# Processing map 5480
# Processing map 5490
# Processing map 5500
# Processing map 5510
# Processing map 5520
# Processing map 5530
# Processing map 5540
# Processing map 5550
# Processing map 5560
# Processing map 5570
# Processing map 5580
# Processing map 5590
# Processing map 5600
# Processing map 5610
# Processing map 5620
# Processing map 5630
# Processing map 5640
# Processing map 5650
# Processing map 5660
# Processing map 5670
# Processing map 5680
# Processing map 5690
# Processing map 5700
# Processing map 5710
# Processing map 5720
# Processing map 5730
# Processing map 5740
# Processing map 5750
# Processing map 5760
# Processing map 5770
# Processing map 5780
# Processing map 5790
# Processing map 5800
# Processing map 5810
# Processing map 5820
# Processing map 5830
# Processing map 5840
# Processing map 5850
# Processing map 5860
# Processing map 5870
# Processing map 5880
# Processing map 5890
# Processing map 5900
# Processing map 5910
# Processing map 5920
# Processing map 5930
# Processing map 5940
# Processing map 5950
# Processing map 5960
# Processing map 5970
# Processing map 5980
# Processing map 5990
# Processing map 6000
# Processing map 6010
# Processing map 6020
# Processing map 6030
# Processing map 6040
# Processing map 6050
# Processing map 6060
# Processing map 6070
# Processing map 6080
# Processing map 6090
# Processing map 6100
# Processing map 6110
# Processing map 6120
# Processing map 6130
# Processing map 6140
# Processing map 6150
# Processing map 6160
# Processing map 6170
# Processing map 6180
# Processing map 6190
# Processing map 6200
# Processing map 6210
# Processing map 6220
# Processing map 6230
# Processing map 6240
# Processing map 6250
# Processing map 6260
# Processing map 6270
# Processing map 6280
# Processing map 6290
# Processing map 6300
# Processing map 6310
# Processing map 6320
# Processing map 6330
# Processing map 6340
# Processing map 6350
# Processing map 6360
# Processing map 6370
# Processing map 6380
# Processing map 6390
# Processing map 6400
# Processing map 6410
# Processing map 6420
# Processing map 6430
# Processing map 6440
# Processing map 6450
# Processing map 6460
# Processing map 6470
# Processing map 6480
# Processing map 6490
# Processing map 6500
# Processing map 6510
# Processing map 6520
# Processing map 6530
# Processing map 6540
# Processing map 6550
# Processing map 6560
# Processing map 6570
# Processing map 6580
# Processing map 6590
# Processing map 6600
# Processing map 6610
# Processing map 6620
# Processing map 6630
# Processing map 6640
# Processing map 6650
# Processing map 6660
# Processing map 6670
# Processing map 6680
# Processing map 6690
# Processing map 6700
# Processing map 6710
# Processing map 6720
# Processing map 6730
# Processing map 6740
# Processing map 6750
# Processing map 6760
# Processing map 6770
# Processing map 6780
# Processing map 6790
# Processing map 6800
# Processing map 6810
# Processing map 6820
# Processing map 6830
# Processing map 6840
# Processing map 6850
# Processing map 6860
# Processing map 6870
# Processing map 6880
# Processing map 6890
# Processing map 6900
# Processing map 6910
# Processing map 6920
# Processing map 6930
# Processing map 6940
# Processing map 6950
# Processing map 6960
# Processing map 6970
# Processing map 6980
# Processing map 6990
# Processing map 7000
# Processing map 7010
# Processing map 7020
# Processing map 7030
# Processing map 7040
# Processing map 7050
# Processing map 7060
# Processing map 7070
# Processing map 7080
# Processing map 7090
# Processing map 7100
# Processing map 7110
# Processing map 7120
# Processing map 7130
# Processing map 7140
# Processing map 7150
# Processing map 7160
# Processing map 7170
# Processing map 7180
# Processing map 7190
# Processing map 7200
# Processing map 7210
# Processing map 7220
# Processing map 7230
# Processing map 7240
# Processing map 7250
# Processing map 7260
# Processing map 7270
# Processing map 7280
# Processing map 7290
# Processing map 7300
# Processing map 7310
# Processing map 7320
# Processing map 7330
# Processing map 7340
# Processing map 7350
# Processing map 7360
# Processing map 7370
# Processing map 7380
# Processing map 7390
# Processing map 7400
# Processing map 7410
# Processing map 7420
# Processing map 7430
# Processing map 7440
# Processing map 7450
# Processing map 7460
# Processing map 7470
# Processing map 7480
# Processing map 7490
# Processing map 7500
# Processing map 7510
# Processing map 7520
# Processing map 7530
# Processing map 7540
# Processing map 7550
# Processing map 7560
# Processing map 7570
# Processing map 7580
# Processing map 7590
# Processing map 7600
# Processing map 7610
# Processing map 7620
# Processing map 7630
# Processing map 7640
# Processing map 7650
# Processing map 7660
# Processing map 7670
# Processing map 7680
# Processing map 7690
# Processing map 7700
# Processing map 7710
# Processing map 7720
# Processing map 7730
# Processing map 7740
# Processing map 7750
# Processing map 7760
# Processing map 7770
# Processing map 7780
# Processing map 7790
# Processing map 7800
# Processing map 7810
# Processing map 7820
# Processing map 7830
# Processing map 7840
# Processing map 7850
# Processing map 7860
# Processing map 7870
# Processing map 7880
# Processing map 7890
# Processing map 7900
# Processing map 7910
# Processing map 7920
# Processing map 7930
# Processing map 7940
# Processing map 7950
# Processing map 7960
# Processing map 7970
# Processing map 7980
# Processing map 7990
# Processing map 8000
# Processing map 8010
# Processing map 8020
# Processing map 8030
# Processing map 8040
# Processing map 8050
# Processing map 8060
# Processing map 8070
# Processing map 8080
# Processing map 8090
# Processing map 8100
# Processing map 8110
# Processing map 8120
# Processing map 8130
# Processing map 8140
# Processing map 8150
# Processing map 8160
# Processing map 8170
# Processing map 8180
# Processing map 8190
# Processing map 8200
# Processing map 8210
# Processing map 8220
# Processing map 8230
# Processing map 8240
# Processing map 8250
# Processing map 8260
# Processing map 8270
# Processing map 8280
# Processing map 8290
# Processing map 8300
# Processing map 8310
# Processing map 8320
# Processing map 8330
# Processing map 8340
# Processing map 8350
# Processing map 8360
# Processing map 8370
# Processing map 8380
# Processing map 8390
# Processing map 8400
# Processing map 8410
# Processing map 8420
# Processing map 8430
# Processing map 8440
# Processing map 8450
# Processing map 8460
# Processing map 8470
# Processing map 8480
# Processing map 8490
# Processing map 8500
# Processing map 8510
# Processing map 8520
# Processing map 8530
# Processing map 8540
# Processing map 8550
# Processing map 8560
# Processing map 8570
# Processing map 8580
# Processing map 8590
# Processing map 8600
# Processing map 8610
# Processing map 8620
# Processing map 8630
# Processing map 8640
# Processing map 8650
# Processing map 8660
# Processing map 8670
# Processing map 8680
# Processing map 8690
# Processing map 8700
# Processing map 8710
# Processing map 8720
# Processing map 8730
# Processing map 8740
# Processing map 8750
# Processing map 8760
# Processing map 8770
# Processing map 8780
# Processing map 8790
# Processing map 8800
# Processing map 8810
# Processing map 8820
# Processing map 8830
# Processing map 8840
# Processing map 8850
# Processing map 8860
# Processing map 8870
# Processing map 8880
# Processing map 8890
# Processing map 8900
# Processing map 8910
# Processing map 8920
# Processing map 8930
# Processing map 8940
# Processing map 8950
# Processing map 8960
# Processing map 8970
# Processing map 8980
# Processing map 8990
# Processing map 9000
# Processing map 9010
# Processing map 9020
# Processing map 9030
# Processing map 9040
# Processing map 9050
# Processing map 9060
# Processing map 9070
# Processing map 9080
# Processing map 9090
# Processing map 9100
# Processing map 9110
# Processing map 9120
# Processing map 9130
# Processing map 9140
# Processing map 9150
# Processing map 9160
# Processing map 9170
# Processing map 9180
# Processing map 9190
# Processing map 9200
# Processing map 9210
# Processing map 9220
# Processing map 9230
# Processing map 9240
# Processing map 9250
# Processing map 9260
# Processing map 9270
# Processing map 9280
# Processing map 9290
# Processing map 9300
# Processing map 9310
# Processing map 9320
# Processing map 9330
# Processing map 9340
# Processing map 9350
# Processing map 9360
# Processing map 9370
# Processing map 9380
# Processing map 9390
# Processing map 9400
# Processing map 9410
# Processing map 9420
# Processing map 9430
# Processing map 9440
# Processing map 9450
# Processing map 9460
# Processing map 9470
# Processing map 9480
# Processing map 9490
# Processing map 9500
# Processing map 9510
# Processing map 9520
# Processing map 9530
# Processing map 9540
# Processing map 9550
# Processing map 9560
# Processing map 9570
# Processing map 9580
# Processing map 9590
# Processing map 9600
# Processing map 9610
# Processing map 9620
# Processing map 9630
# Processing map 9640
# Processing map 9650
# Processing map 9660
# Processing map 9670
# Processing map 9680
# Processing map 9690
# Processing map 9700
# Processing map 9710
# Processing map 9720
# Processing map 9730
# Processing map 9740
# Processing map 9750
# Processing map 9760
# Processing map 9770
# Processing map 9780
# Processing map 9790
# Processing map 9800
# Processing map 9810
# Processing map 9820
# Processing map 9830
# Processing map 9840
# Processing map 9850
# Processing map 9860
# Processing map 9870
# Processing map 9880
# Processing map 9890
# Processing map 9900
# Processing map 9910
# Processing map 9920
# Processing map 9930
# Processing map 9940
# Processing map 9950
# Processing map 9960
# Processing map 9970
# Processing map 9980
# Processing map 9990
# Processing map 10000
# Processing map 10010
# Processing map 10020
# Processing map 10030
# Processing map 10040
# Processing map 10050
# Processing map 10060
# Processing map 10070
# Processing map 10080
# Processing map 10090
# Processing map 10100
# Processing map 10110
# Processing map 10120
# Processing map 10130
# Processing map 10140
# Processing map 10150
# Processing map 10160
# Processing map 10170
# Processing map 10180
# Processing map 10190
# Processing map 10200
# Processing map 10210
# Processing map 10220
# Processing map 10230
# Processing map 10240
# Processing map 10250
# Processing map 10260
# Processing map 10270
# Processing map 10280
# Processing map 10290
# Processing map 10300
# Processing map 10310
# Processing map 10320
# Processing map 10330
# Processing map 10340
# Processing map 10350
# Processing map 10360
# Processing map 10370
# Processing map 10380
# Processing map 10390
# Processing map 10400
# Processing map 10410
# Processing map 10420
# Processing map 10430
# Processing map 10440
# Processing map 10450
# Processing map 10460
# Processing map 10470
# Processing map 10480
# Processing map 10490
# Processing map 10500
# Processing map 10510
# Processing map 10520
# Processing map 10530
# Processing map 10540
# Processing map 10550
# Processing map 10560
# Processing map 10570
# Processing map 10580
# Processing map 10590
# Processing map 10600
# Processing map 10610
# Processing map 10620
# Processing map 10630
# Processing map 10640
# Processing map 10650
# Processing map 10660
# Processing map 10670
# Processing map 10680
# Processing map 10690
# Processing map 10700
# Processing map 10710
# Processing map 10720
# Processing map 10730
# Processing map 10740
# Processing map 10750
# Processing map 10760
# Processing map 10770
# Processing map 10780
# Processing map 10790
# Processing map 10800
# Processing map 10810
# Processing map 10820
# Processing map 10830
# Processing map 10840
# Processing map 10850
# Processing map 10860
# Processing map 10870
# Processing map 10880
# Processing map 10890
# Processing map 10900
# Processing map 10910
# Processing map 10920
# Processing map 10930
# Processing map 10940
# Processing map 10950
# Processing map 10960
# Processing map 10970
# Processing map 10980
# Processing map 10990
# Processing map 11000
# Processing map 11010
# Processing map 11020
# Processing map 11030
# Processing map 11040
# Processing map 11050
# Processing map 11060
# Processing map 11070
# Processing map 11080
# Processing map 11090
# Processing map 11100
# Processing map 11110
# Processing map 11120
# Processing map 11130
# Processing map 11140
# Processing map 11150
# Processing map 11160
# Processing map 11170
# Processing map 11180
# Processing map 11190
# Processing map 11200
# Processing map 11210
# Processing map 11220
# Processing map 11230
# Processing map 11240
# Processing map 11250
# Processing map 11260
# Processing map 11270
# Processing map 11280
# Processing map 11290
# Processing map 11300
# Processing map 11310
# Processing map 11320
# Processing map 11330
# Processing map 11340
# Processing map 11350
# Processing map 11360
# Processing map 11370
# Processing map 11380
# Processing map 11390
# Processing map 11400
# Processing map 11410
# Processing map 11420
# Processing map 11430
# Processing map 11440
# Processing map 11450
# Processing map 11460
# Processing map 11470
# Processing map 11480
# Processing map 11490
# Processing map 11500
# Processing map 11510
# Processing map 11520
# Processing map 11530
# Processing map 11540
# Processing map 11550
# Processing map 11560
# Processing map 11570
# Processing map 11580
# Processing map 11590
# Processing map 11600
# Processing map 11610
# Processing map 11620
# Processing map 11630
# Processing map 11640
# Processing map 11650
# Processing map 11660
# Processing map 11670
# Processing map 11680
# Processing map 11690
# Processing map 11700
# Processing map 11710
# Processing map 11720
# Processing map 11730
# Processing map 11740
# Processing map 11750
# Processing map 11760
# Processing map 11770
# Processing map 11780
# Processing map 11790
# Processing map 11800
# Processing map 11810
# Processing map 11820
# Processing map 11830
# Processing map 11840
# Processing map 11850
# Processing map 11860
# Processing map 11870
# Processing map 11880
# Processing map 11890
# Processing map 11900
# Processing map 11910
# Processing map 11920
# Processing map 11930
# Processing map 11940
# Processing map 11950
# Processing map 11960
# Processing map 11970
# Processing map 11980
# Processing map 11990
# Processing map 12000
# Processing map 12010
# Processing map 12020
# Processing map 12030
# Processing map 12040
# Processing map 12050
# Processing map 12060
# Processing map 12070
# Processing map 12080
# Processing map 12090
# Processing map 12100
# Processing map 12110
# Processing map 12120
# Processing map 12130
# Processing map 12140
# Processing map 12150
# Processing map 12160
# Processing map 12170
# Processing map 12180
# Processing map 12190
# Processing map 12200
# Processing map 12210
# Processing map 12220
# Processing map 12230
# Processing map 12240
# Processing map 12250
# Processing map 12260
# Processing map 12270
# Processing map 12280
# Processing map 12290
# Processing map 12300
# Processing map 12310
# Processing map 12320
# Processing map 12330
# Processing map 12340
# Processing map 12350
# Processing map 12360
# Processing map 12370
# Processing map 12380
# Processing map 12390
# Processing map 12400
# Processing map 12410
# Processing map 12420
# Processing map 12430
# Processing map 12440
# Processing map 12450
# Processing map 12460
# Processing map 12470
# Processing map 12480
# Processing map 12490
# Processing map 12500
# Processing map 12510
# Processing map 12520
# Processing map 12530
# Processing map 12540
# Processing map 12550
# Processing map 12560
# Processing map 12570
# Processing map 12580
# Processing map 12590
# Processing map 12600
# Processing map 12610
# Processing map 12620
# Processing map 12630
# Processing map 12640
# Processing map 12650
# Processing map 12660
# Processing map 12670
# Processing map 12680
# Processing map 12690
# Processing map 12700
# Processing map 12710
# Processing map 12720
# Processing map 12730
# Processing map 12740
# Processing map 12750
# Processing map 12760
# Processing map 12770
# Processing map 12780
# Processing map 12790
# Processing map 12800
# Processing map 12810
# Processing map 12820
# Processing map 12830
# Processing map 12840
# Processing map 12850
# Processing map 12860
# Processing map 12870
# Processing map 12880
# Processing map 12890
# Processing map 12900
# Processing map 12910
# Processing map 12920
# Processing map 12930
# Processing map 12940
# Processing map 12950
# Processing map 12960
# Processing map 12970
# Processing map 12980
# Processing map 12990
# Processing map 13000
# Processing map 13010
# Processing map 13020
# Processing map 13030
# Processing map 13040
# Processing map 13050
# Processing map 13060
# Processing map 13070
# Processing map 13080
# Processing map 13090
# Processing map 13100
# Processing map 13110
# Processing map 13120
# Processing map 13130
# Processing map 13140
# Processing map 13150
# Processing map 13160
# Processing map 13170
# Processing map 13180
# Processing map 13190
# Processing map 13200
# Processing map 13210
# Processing map 13220
# Processing map 13230
# Processing map 13240
# Processing map 13250
# Processing map 13260
# Processing map 13270
# Processing map 13280
# Processing map 13290
# Processing map 13300
# Processing map 13310
# Processing map 13320
# Processing map 13330
# Processing map 13340
# Processing map 13350
# Processing map 13360
# Processing map 13370
# Processing map 13380
# Processing map 13390
# Processing map 13400
# Processing map 13410
# Processing map 13420
# Processing map 13430
# Processing map 13440
# Processing map 13450
# Processing map 13460
# Processing map 13470
# Processing map 13480
# Processing map 13490
# Processing map 13500
# Processing map 13510
# Processing map 13520
# Processing map 13530
# Processing map 13540
# Processing map 13550
# Processing map 13560
# Processing map 13570
# Processing map 13580
# Processing map 13590
# Processing map 13600
# Processing map 13610
# Processing map 13620
# Processing map 13630
# Processing map 13640
# Processing map 13650
# Processing map 13660
# Processing map 13670
# Processing map 13680
# Processing map 13690
# Processing map 13700
# Processing map 13710
# Processing map 13720
# Processing map 13730
# Processing map 13740
# Processing map 13750
# Processing map 13760
# Processing map 13770
# Processing map 13780
# Processing map 13790
# Processing map 13800
# Processing map 13810
# Processing map 13820
# Processing map 13830
# Processing map 13840
# Processing map 13850
# Processing map 13860
# Processing map 13870
# Processing map 13880
# Processing map 13890
# Processing map 13900
# Processing map 13910
# Processing map 13920
# Processing map 13930
# Processing map 13940
# Processing map 13950
# Processing map 13960
# Processing map 13970
# Processing map 13980
# Processing map 13990
# Processing map 14000
# Processing map 14010
# Processing map 14020
# Processing map 14030
# Processing map 14040
# Processing map 14050
# Processing map 14060
# Processing map 14070
# Processing map 14080
# Processing map 14090
# Processing map 14100
# Processing map 14110
# Processing map 14120
# Processing map 14130
# Processing map 14140
# Processing map 14150
# Processing map 14160
# Processing map 14170
# Processing map 14180
# Processing map 14190
# Processing map 14200
# Processing map 14210
# Processing map 14220
# Processing map 14230
# Processing map 14240
# Processing map 14250
# Processing map 14260
# Processing map 14270
# Processing map 14280
# Processing map 14290
# Processing map 14300
# Processing map 14310
# Processing map 14320
# Processing map 14330
# Processing map 14340
# Processing map 14350
# Processing map 14360
# Processing map 14370
# Processing map 14380
# Processing map 14390
# Processing map 14400
# Processing map 14410
# Processing map 14420
# Processing map 14430
# Processing map 14440
# Processing map 14450
# Processing map 14460
# Processing map 14470
# Processing map 14480
# Processing map 14490
# Processing map 14500
# Processing map 14510
# Processing map 14520
# Processing map 14530
# Processing map 14540
# Processing map 14550
# Processing map 14560
# Processing map 14570
# Processing map 14580
# Processing map 14590
# Processing map 14600
# Processing map 14610
# Processing map 14620
# Processing map 14630
# Processing map 14640
# Processing map 14650
# Processing map 14660
# Processing map 14670
# Processing map 14680
# Processing map 14690
# Processing map 14700
# Processing map 14710
# Processing map 14720
# Processing map 14730
# Processing map 14740
# Processing map 14750
# Processing map 14760
# Processing map 14770
# Processing map 14780
# Processing map 14790
# Processing map 14800
# Processing map 14810
# Processing map 14820
# Processing map 14830
# Processing map 14840
# Processing map 14850
# Processing map 14860
# Processing map 14870
# Processing map 14880
# Processing map 14890
# Processing map 14900
# Processing map 14910
# Processing map 14920
# Processing map 14930
# Processing map 14940
# Processing map 14950
# Processing map 14960
# Processing map 14970
# Processing map 14980
# Processing map 14990
# Processing map 15000
# Processing map 15010
# Processing map 15020
# Processing map 15030
# Processing map 15040
# Processing map 15050
# Processing map 15060
# Processing map 15070
# Processing map 15080
# Processing map 15090
# Processing map 15100
# Processing map 15110
# Processing map 15120
# Processing map 15130
# Processing map 15140
# Processing map 15150
# Processing map 15160
# Processing map 15170
# Processing map 15180
# Processing map 15190
# Processing map 15200
# Processing map 15210
# Processing map 15220
# Processing map 15230
# Processing map 15240
# Processing map 15250
# Processing map 15260
# Processing map 15270
# Processing map 15280
# Processing map 15290
# Processing map 15300
# Processing map 15310
# Processing map 15320
# Processing map 15330
# Processing map 15340
# Processing map 15350
# Processing map 15360
# Processing map 15370
# Processing map 15380
# Processing map 15390
# Processing map 15400
# Processing map 15410
# Processing map 15420
# Processing map 15430
# Processing map 15440
# Processing map 15450
# Processing map 15460
# Processing map 15470
# Processing map 15480
# Processing map 15490
# Processing map 15500
# Processing map 15510
# Processing map 15520
# Processing map 15530
# Processing map 15540
# Processing map 15550
# Processing map 15560
# Processing map 15570
# Processing map 15580
# Processing map 15590
# Processing map 15600
# Processing map 15610
# Processing map 15620
# Processing map 15630
# Processing map 15640
# Processing map 15650
# Processing map 15660
# Processing map 15670
# Processing map 15680
# Processing map 15690
# Processing map 15700
# Processing map 15710
# Processing map 15720
# Processing map 15730
# Processing map 15740
# Processing map 15750
# Processing map 15760
# Processing map 15770
# Processing map 15780
# Processing map 15790
# Processing map 15800
# Processing map 15810
# Processing map 15820
# Processing map 15830
# Processing map 15840
# Processing map 15850
# Processing map 15860
# Processing map 15870
# Processing map 15880
# Processing map 15890
# Processing map 15900
# Processing map 15910
# Processing map 15920
# Processing map 15930
# Processing map 15940
# Processing map 15950
# Processing map 15960
# Processing map 15970
# Processing map 15980
# Processing map 15990
# Processing map 16000
# Processing map 16010
# Processing map 16020
# Processing map 16030
# Processing map 16040
# Processing map 16050
# Processing map 16060
# Processing map 16070
# Processing map 16080
# Processing map 16090
# Processing map 16100
# Processing map 16110
# Processing map 16120
# Processing map 16130
# Processing map 16140
# Processing map 16150
# Processing map 16160
# Processing map 16170
# Processing map 16180
# Processing map 16190
# Processing map 16200
# Processing map 16210
# Processing map 16220
# Processing map 16230
# Processing map 16240
# Processing map 16250
# Processing map 16260
# Processing map 16270
# Processing map 16280
# Processing map 16290
# Processing map 16300
# Processing map 16310
# Processing map 16320
# Processing map 16330
# Processing map 16340
# Processing map 16350
# Processing map 16360
# Processing map 16370
# Processing map 16380
# Processing map 16390
# Processing map 16400
# Processing map 16410
# Processing map 16420
# Processing map 16430
# Processing map 16440
# Processing map 16450
# Processing map 16460
# Processing map 16470
# Processing map 16480
# Processing map 16490
# Processing map 16500
# Processing map 16510
# Processing map 16520
# Processing map 16530
# Processing map 16540
# Processing map 16550
# Processing map 16560
# Processing map 16570
# Processing map 16580
# Processing map 16590
# Processing map 16600
# Processing map 16610
# Processing map 16620
# Processing map 16630
# Processing map 16640
# Processing map 16650
# Processing map 16660
# Processing map 16670
# Processing map 16680
# Processing map 16690
# Processing map 16700
# Processing map 16710
# Processing map 16720
# Processing map 16730
# Processing map 16740
# Processing map 16750
# Processing map 16760
# Processing map 16770
# Processing map 16780
# Processing map 16790
# Processing map 16800
# Processing map 16810
# Processing map 16820
# Processing map 16830
# Processing map 16840
# Processing map 16850
# Processing map 16860
# Processing map 16870
# Processing map 16880
# Processing map 16890
# Processing map 16900
# Processing map 16910
# Processing map 16920
# Processing map 16930
# Processing map 16940
# Processing map 16950
# Processing map 16960
# Processing map 16970
# Processing map 16980
# Processing map 16990
# Processing map 17000
# Processing map 17010
# Processing map 17020
# Processing map 17030
# Processing map 17040
# Processing map 17050
# Processing map 17060
# Processing map 17070
# Processing map 17080
# Processing map 17090
# Processing map 17100
# Processing map 17110
# Processing map 17120
# Processing map 17130
# Processing map 17140
# Processing map 17150
# Processing map 17160
# Processing map 17170
# Processing map 17180
# Processing map 17190
# Processing map 17200
# Processing map 17210
# Processing map 17220
# Processing map 17230
# Processing map 17240
# Processing map 17250
# Processing map 17260
# Processing map 17270
# Processing map 17280
# Processing map 17290
# Processing map 17300
# Processing map 17310
# Processing map 17320
# Processing map 17330
# Processing map 17340
# Processing map 17350
# Processing map 17360
# Processing map 17370
# Processing map 17380
# Processing map 17390
# Processing map 17400
# Processing map 17410
# Processing map 17420
# Processing map 17430
# Processing map 17440
# Processing map 17450
# Processing map 17460
# Processing map 17470
# Processing map 17480
# Processing map 17490
# Processing map 17500
# Processing map 17510
# Processing map 17520
# Processing map 17530
# Processing map 17540
# Processing map 17550
# Processing map 17560
# Processing map 17570
# Processing map 17580
# Processing map 17590
# Processing map 17600
# Processing map 17610
# Processing map 17620
# Processing map 17630
# Processing map 17640
# Processing map 17650
# Processing map 17660
# Processing map 17670
# Processing map 17680
# Processing map 17690
# Processing map 17700
# Processing map 17710
# Processing map 17720
# Processing map 17730
# Processing map 17740
# Processing map 17750
# Processing map 17760
# Processing map 17770
# Processing map 17780
# Processing map 17790
# Processing map 17800
# Processing map 17810
# Processing map 17820
# Processing map 17830
# Processing map 17840
# Processing map 17850
# Processing map 17860
# Processing map 17870
# Processing map 17880
# Processing map 17890
# Processing map 17900
# Processing map 17910
# Processing map 17920
# Processing map 17930
# Processing map 17940
# Processing map 17950
# Processing map 17960
# Processing map 17970
# Processing map 17980
# Processing map 17990
# Processing map 18000
# Processing map 18010
# Processing map 18020
# Processing map 18030
# Processing map 18040
# Processing map 18050
# Processing map 18060
# Processing map 18070
# Processing map 18080
# Processing map 18090
# Processing map 18100
# Processing map 18110
# Processing map 18120
# Processing map 18130
# Processing map 18140
# Processing map 18150
# Processing map 18160
# Processing map 18170
# Processing map 18180
# Processing map 18190
# Processing map 18200
# Processing map 18210
# Processing map 18220
# Processing map 18230
# Processing map 18240
# Processing map 18250
# Processing map 18260
# Processing map 18270
# Processing map 18280
# Processing map 18290
# Processing map 18300
# Processing map 18310
# Processing map 18320
# Processing map 18330
# Processing map 18340
# Processing map 18350
# Processing map 18360
# Processing map 18370
# Processing map 18380
# Processing map 18390
# Processing map 18400
# Processing map 18410
# Processing map 18420
# Processing map 18430
# Processing map 18440
# Processing map 18450
# Processing map 18460
# Processing map 18470
# Processing map 18480
# Processing map 18490
# Processing map 18500
# Processing map 18510
# Processing map 18520
# Processing map 18530
# Processing map 18540
# Processing map 18550
# Processing map 18560
# Processing map 18570
# Processing map 18580
# Processing map 18590
# Processing map 18600
# Processing map 18610
# Processing map 18620
# Processing map 18630
# Processing map 18640
# Processing map 18650
# Processing map 18660
# Processing map 18670
# Processing map 18680
# Processing map 18690
# Processing map 18700
# Processing map 18710
# Processing map 18720
# Processing map 18730
# Processing map 18740
# Processing map 18750
# Processing map 18760
# Processing map 18770
# Processing map 18780
# Processing map 18790
# Processing map 18800
# Processing map 18810
# Processing map 18820
# Processing map 18830
# Processing map 18840
# Processing map 18850
# Processing map 18860
# Processing map 18870
# Processing map 18880
# Processing map 18890
# Processing map 18900
# Processing map 18910
# Processing map 18920
# Processing map 18930
# Processing map 18940
# Processing map 18950
# Processing map 18960
# Processing map 18970
# Processing map 18980
# Processing map 18990
# Processing map 19000
# Processing map 19010
# Processing map 19020
# Processing map 19030
# Processing map 19040
# Processing map 19050
# Processing map 19060
# Processing map 19070
# Processing map 19080
# Processing map 19090
# Processing map 19100
# Processing map 19110
# Processing map 19120
# Processing map 19130
# Processing map 19140
# Processing map 19150
# Processing map 19160
# Processing map 19170
# Processing map 19180
# Processing map 19190
# Processing map 19200
# Processing map 19210
# Processing map 19220
# Processing map 19230
# Processing map 19240
# Processing map 19250
# Processing map 19260
# Processing map 19270
# Processing map 19280
# Processing map 19290
# Processing map 19300
# Processing map 19310
# Processing map 19320
# Processing map 19330
# Processing map 19340
# Processing map 19350
# Processing map 19360
# Processing map 19370
# Processing map 19380
# Processing map 19390
# Processing map 19400
# Processing map 19410
# Processing map 19420
# Processing map 19430
# Processing map 19440
# Processing map 19450
# Processing map 19460
# Processing map 19470
# Processing map 19480
# Processing map 19490
# Processing map 19500
# Processing map 19510
# Processing map 19520
# Processing map 19530
# Processing map 19540
# Processing map 19550
# Processing map 19560
# Processing map 19570
# Processing map 19580
# Processing map 19590
# Processing map 19600
# Processing map 19610
# Processing map 19620
# Processing map 19630
# Processing map 19640
# Processing map 19650
# Processing map 19660
# Processing map 19670
# Processing map 19680
# Processing map 19690
# Processing map 19700
# Processing map 19710
# Processing map 19720
# Processing map 19730
# Processing map 19740
# Processing map 19750
# Processing map 19760
# Processing map 19770
# Processing map 19780
# Processing map 19790
# Processing map 19800
# Processing map 19810
# Processing map 19820
# Processing map 19830
# Processing map 19840
# Processing map 19850
# Processing map 19860
# Processing map 19870
# Processing map 19880
# Processing map 19890
# Processing map 19900
# Processing map 19910
# Processing map 19920
# Processing map 19930
# Processing map 19940
# Processing map 19950
# Processing map 19960
# Processing map 19970
# Processing map 19980
# Processing map 19990
# Processing map 20000
# Processing map 20010
# Processing map 20020
# Processing map 20030
# Processing map 20040
# Processing map 20050
# Processing map 20060
# ...
# Processing map 20750
# Processing map 20760
# Processing map 20770
# Processing map 20780
# Processing map 20790
# Processing map 20800
# Processing map 20810
# Processing map 20820
# Processing map 20830
# Processing map 20840
# Processing map 20850
# Processing map 20860
# Processing map 20870
# Processing map 20880
# Processing map 20890
# Processing map 20900
# Processing map 20910
# Processing map 20920
# Processing map 20930
# Processing map 20940
# Processing map 20950
# Processing map 20960
# Processing map 20970
# Processing map 20980
# Processing map 20990
# Processing map 21000
# Processing map 21010
# Processing map 21020
# Processing map 21030
# Processing map 21040
# Processing map 21050
# Processing map 21060
# Processing map 21070
# Processing map 21080
# Processing map 21090
# Processing map 21100
# Processing map 21110
# Processing map 21120
# Processing map 21130
# Processing map 21140
# Processing map 21150
# Processing map 21160
# Processing map 21170
# Processing map 21180
# Processing map 21190
# Processing map 21200
# Processing map 21210
# Processing map 21220
# Processing map 21230
# Processing map 21240
# Processing map 21250
# Processing map 21260
# Processing map 21270
# Processing map 21280
# Processing map 21290
# Processing map 21300
# Processing map 21310
# Processing map 21320
# Processing map 21330
# Processing map 21340
# Processing map 21350
# Processing map 21360
# Processing map 21370
# Processing map 21380
# Processing map 21390
# Processing map 21400
# Processing map 21410
# Processing map 21420
# Processing map 21430
# Processing map 21440
# Processing map 21450
# Processing map 21460
# Processing map 21470
# Processing map 21480
# Processing map 21490
# Processing map 21500
# Processing map 21510
# Processing map 21520
# Processing map 21530
# Processing map 21540
# Processing map 21550
# Processing map 21560
# Processing map 21570
# Processing map 21580
# Processing map 21590
# Processing map 21600
# Processing map 21610
# Processing map 21620
# Processing map 21630
# Processing map 21640
# Processing map 21650
# Processing map 21660
# Processing map 21670
# Processing map 21680
# Processing map 21690
# Processing map 21700
# Processing map 21710
# Processing map 21720
# Processing map 21730
# Processing map 21740
# Processing map 21750
# Processing map 21760
# Processing map 21770
# Processing map 21780
# Processing map 21790
# Processing map 21800
# Processing map 21810
# Processing map 21820
# Processing map 21830
# Processing map 21840
# Processing map 21850
# Processing map 21860
# Processing map 21870
# Processing map 21880
# Processing map 21890
# Processing map 21900
# Processing map 21910
# Processing map 21920
# Processing map 21930
# Processing map 21940
# Processing map 21950
# Processing map 21960
# Processing map 21970
# Processing map 21980
# Processing map 21990
# Processing map 22000
# Processing map 22010
# Processing map 22020
# Processing map 22030
# Processing map 22040
# Processing map 22050
# Processing map 22060
# Processing map 22070
# Processing map 22080
# Processing map 22090
# Processing map 22100
# Processing map 22110
# Processing map 22120
# Processing map 22130
# Processing map 22140
# Processing map 22150
# Processing map 22160
# Processing map 22170
# Processing map 22180
# Processing map 22190
# Processing map 22200
# Processing map 22210
# Processing map 22220
# Processing map 22230
# Processing map 22240
# Processing map 22250
# Processing map 22260
# Processing map 22270
# Processing map 22280
# Processing map 22290
# Processing map 22300
# Processing map 22310
# Processing map 22320
# Processing map 22330
# Processing map 22340
# Processing map 22350
# Processing map 22360
# Processing map 22370
# Processing map 22380
# Processing map 22390
# Processing map 22400
# Processing map 22410
# Processing map 22420
# Processing map 22430
# Processing map 22440
# Processing map 22450
# Processing map 22460
# Processing map 22470
# Processing map 22480
# Processing map 22490
# Processing map 22500
# Processing map 22510
# Processing map 22520
# Processing map 22530
# Processing map 22540
# Processing map 22550
# Processing map 22560
# Processing map 22570
# Processing map 22580
# Processing map 22590
# Processing map 22600
# Processing map 22610
# Processing map 22620
# Processing map 22630
# Processing map 22640
# Processing map 22650
# Processing map 22660
# Processing map 22670
# Processing map 22680
# Processing map 22690
# Processing map 22700
# Processing map 22710
# Processing map 22720
# Processing map 22730
# Processing map 22740
# Processing map 22750
# Processing map 22760
# Processing map 22770
# Processing map 22780
# Processing map 22790
# Processing map 22800
# Processing map 22810
# Processing map 22820
# Processing map 22830
# Processing map 22840
# Processing map 22850
# Processing map 22860
# Processing map 22870
# Processing map 22880
# Processing map 22890
# Processing map 22900
# Processing map 22910
# Processing map 22920
# Processing map 22930
# Processing map 22940
# Processing map 22950
# Processing map 22960
# Processing map 22970
# Processing map 22980
# Processing map 22990
# Processing map 23000
# Processing map 23010
# Processing map 23020
# Processing map 23030
# Processing map 23040
# Processing map 23050
# Processing map 23060
# Processing map 23070
# Processing map 23080
# Processing map 23090
# Processing map 23100
# Processing map 23110
# Processing map 23120
# Processing map 23130
# Processing map 23140
# Processing map 23150
# Processing map 23160
# Processing map 23170
# Processing map 23180
# Processing map 23190
# Processing map 23200
# Processing map 23210
# Processing map 23220
# Processing map 23230
# Processing map 23240
# Processing map 23250
# Processing map 23260
# Processing map 23270
# Processing map 23280
# Processing map 23290
# Processing map 23300
# Processing map 23310
# Processing map 23320
# Processing map 23330
# Processing map 23340
# Processing map 23350
# Processing map 23360
# Processing map 23370
# Processing map 23380
# Processing map 23390
# Processing map 23400
# Processing map 23410
# Processing map 23420
# Processing map 23430
# Processing map 23440
# Processing map 23450
# Processing map 23460
# Processing map 23470
# Processing map 23480
# Processing map 23490
# Processing map 23500
# Processing map 23510
# Processing map 23520
# Processing map 23530
# Processing map 23540
# Processing map 23550
# Processing map 23560
# Processing map 23570
# Processing map 23580
# Processing map 23590
# Processing map 23600
# Processing map 23610
# Processing map 23620
# Processing map 23630
# Processing map 23640
# Processing map 23650
# Processing map 23660
# Processing map 23670
# Processing map 23680
# Processing map 23690
# Processing map 23700
# Processing map 23710
# Processing map 23720
# Processing map 23730
# Processing map 23740
# Processing map 23750
# Processing map 23760
# Processing map 23770
# Processing map 23780
# Processing map 23790
# Processing map 23800
# Processing map 23810
# Processing map 23820
# Processing map 23830
# Processing map 23840
# Processing map 23850
# Processing map 23860
# Processing map 23870
# Processing map 23880
# Processing map 23890
# Processing map 23900
# Processing map 23910
# Processing map 23920
# Processing map 23930
# Processing map 23940
# Processing map 23950
# Processing map 23960
# Processing map 23970
# Processing map 23980
# Processing map 23990
# Processing map 24000
# Processing map 24010
# Processing map 24020
# Processing map 24030
# Processing map 24040
# Processing map 24050
# Processing map 24060
# Processing map 24070
# Processing map 24080
# Processing map 24090
# Processing map 24100
# Processing map 24110
# Processing map 24120
# Processing map 24130
# Processing map 24140
# Processing map 24150
# Processing map 24160
# Processing map 24170
# Processing map 24180
# Processing map 24190
# Processing map 24200
# Processing map 24210
# Processing map 24220
# Processing map 24230
# Processing map 24240
# Processing map 24250
# Processing map 24260
# Processing map 24270
# Processing map 24280
# Processing map 24290
# Processing map 24300
# Processing map 24310
# Processing map 24320
# Processing map 24330
# Processing map 24340
# Processing map 24350
# Processing map 24360
# Processing map 24370
# Processing map 24380
# Processing map 24390
# Processing map 24400
# Processing map 24410
# Processing map 24420
# Processing map 24430
# Processing map 24440
# Processing map 24450
# Processing map 24460
# Processing map 24470
# Processing map 24480
# Processing map 24490
# Processing map 24500
# Processing map 24510
# Processing map 24520
# Processing map 24530
# Processing map 24540
# Processing map 24550
# Processing map 24560
# Processing map 24570
# Processing map 24580
# Processing map 24590
# Processing map 24600
# Processing map 24610
# Processing map 24620
# Processing map 24630
# Processing map 24640
# Processing map 24650
# Processing map 24660
# Processing map 24670
# Processing map 24680
# Processing map 24690
# Processing map 24700
# Processing map 24710
# Processing map 24720
# Processing map 24730
# Processing map 24740
# Processing map 24750
# Processing map 24760
# Processing map 24770
# Processing map 24780
# Processing map 24790
# Processing map 24800
# Processing map 24810
# Processing map 24820
# Processing map 24830
# Processing map 24840
# Processing map 24850
# Processing map 24860
# Processing map 24870
# Processing map 24880
# Processing map 24890
# Processing map 24900
# Processing map 24910
# Processing map 24920
# Processing map 24930
# Processing map 24940
# Processing map 24950
# Processing map 24960
# Processing map 24970
# Processing map 24980
# Processing map 24990
# Processing map 25000
# Processing map 25010
# Processing map 25020
# Processing map 25030
# Processing map 25040
# Processing map 25050
# Processing map 25060
# Processing map 25070
# Processing map 25080
# Processing map 25090
# Processing map 25100
# Processing map 25110
# Processing map 25120
# Processing map 25130
# Processing map 25140
# Processing map 25150
# Processing map 25160
# Processing map 25170
# Processing map 25180
# Processing map 25190
# Processing map 25200
# Processing map 25210
# Processing map 25220
# Processing map 25230
# Processing map 25240
# Processing map 25250
# Processing map 25260
# Processing map 25270
# Processing map 25280
# Processing map 25290
# Processing map 25300
# Processing map 25310
# Processing map 25320
# Processing map 25330
# Processing map 25340
# Processing map 25350
# Processing map 25360
# Processing map 25370
# Processing map 25380
# Processing map 25390
# Processing map 25400
# Processing map 25410
# Processing map 25420
# Processing map 25430
# Processing map 25440
# Processing map 25450
# Processing map 25460
# Processing map 25470
# Processing map 25480
# Processing map 25490
# Processing map 25500
# Processing map 25510
# Processing map 25520
# Processing map 25530
# Processing map 25540
# Processing map 25550
# Processing map 25560
# Processing map 25570
# Processing map 25580
# Processing map 25590
# Processing map 25600
# Processing map 25610
# Processing map 25620
# Processing map 25630
# Processing map 25640
# Processing map 25650
# Processing map 25660
# Processing map 25670
# Processing map 25680
# Processing map 25690
# Processing map 25700
# Processing map 25710
# Processing map 25720
# Processing map 25730
# Processing map 25740
# Processing map 25750
# Processing map 25760
# Processing map 25770
# Processing map 25780
# Processing map 25790
# Processing map 25800
# Processing map 25810
# Processing map 25820
# Processing map 25830
# Processing map 25840
# Processing map 25850
# Processing map 25860
# Processing map 25870
# Processing map 25880
# Processing map 25890
# Processing map 25900
# Processing map 25910
# Processing map 25920
# Processing map 25930
# Processing map 25940
# Processing map 25950
# Processing map 25960
# Processing map 25970
# Processing map 25980
# Processing map 25990
# Processing map 26000
# Processing map 26010
# Processing map 26020
# Processing map 26030
# Processing map 26040
# Processing map 26050
# Processing map 26060
# Processing map 26070
# Processing map 26080
# Processing map 26090
# Processing map 26100
# Processing map 26110
# Processing map 26120
# Processing map 26130
# Processing map 26140
# Processing map 26150
# Processing map 26160
# Processing map 26170
# Processing map 26180
# Processing map 26190
# Processing map 26200
# Processing map 26210
# Processing map 26220
# Processing map 26230
# Processing map 26240
# Processing map 26250
# Processing map 26260
# Processing map 26270
# Processing map 26280
# Processing map 26290
# Processing map 26300
# Processing map 26310
# Processing map 26320
# Processing map 26330
# Processing map 26340
# Processing map 26350
# Processing map 26360
# Processing map 26370
# Processing map 26380
# Processing map 26390
# Processing map 26400
# Processing map 26410
# Processing map 26420
# Processing map 26430
# Processing map 26440
# Processing map 26450
# Processing map 26460
# Processing map 26470
# Processing map 26480
# Processing map 26490
# Processing map 26500
# Processing map 26510
# Processing map 26520
# Processing map 26530
# Processing map 26540
# Processing map 26550
# Processing map 26560
# Processing map 26570
# Processing map 26580
# Processing map 26590
# Processing map 26600
# Processing map 26610
# Processing map 26620
# Processing map 26630
# Processing map 26640
# Processing map 26650
# Processing map 26660
# Processing map 26670
# Processing map 26680
# Processing map 26690
# Processing map 26700
# Processing map 26710
# Processing map 26720
# Processing map 26730
# Processing map 26740
# Processing map 26750
# Processing map 26760
# Processing map 26770
# Processing map 26780
# Processing map 26790
# Processing map 26800
# Processing map 26810
# Processing map 26820
# Processing map 26830
# Processing map 26840
# Processing map 26850
# Processing map 26860
# Processing map 26870
# Processing map 26880
# Processing map 26890
# Processing map 26900
# Processing map 26910
# Processing map 26920
# Processing map 26930
# Processing map 26940
# Processing map 26950
# Processing map 26960
# Processing map 26970
# Processing map 26980
# Processing map 26990
# Processing map 27000
# Processing map 27010
# Processing map 27020
# Processing map 27030
# Processing map 27040
# Processing map 27050
# Processing map 27060
# Processing map 27070
# Processing map 27080
# Processing map 27090
# Processing map 27100
# Processing map 27110
# Processing map 27120
# Processing map 27130
# Processing map 27140
# Processing map 27150
# Processing map 27160
# Processing map 27170
# Processing map 27180
# Processing map 27190
# Processing map 27200
# Processing map 27210
# Processing map 27220
# Processing map 27230
# Processing map 27240
# Processing map 27250
# Processing map 27260
# Processing map 27270
# Processing map 27280
# Processing map 27290
# Processing map 27300
# Processing map 27310
# Processing map 27320
# Processing map 27330
# Processing map 27340
# Processing map 27350
# Processing map 27360
# Processing map 27370
# Processing map 27380
# Processing map 27390
# Processing map 27400
# Processing map 27410
# Processing map 27420
# Processing map 27430
# Processing map 27440
# Processing map 27450
# Processing map 27460
# Processing map 27470
# Processing map 27480
# Processing map 27490
# Processing map 27500
# Processing map 27510
# Processing map 27520
# Processing map 27530
# Processing map 27540
# Processing map 27550
# Processing map 27560
# Processing map 27570
# Processing map 27580
# Processing map 27590
# Processing map 27600
# Processing map 27610
# Processing map 27620
# Processing map 27630
# Processing map 27640
# Processing map 27650
# Processing map 27660
# Processing map 27670
# Processing map 27680
# Processing map 27690
# Processing map 27700
# Processing map 27710
# Processing map 27720
# Processing map 27730
# Processing map 27740
# Processing map 27750
# Processing map 27760
# Processing map 27770
# Processing map 27780
# Processing map 27790
# Processing map 27800
# Processing map 27810
# Processing map 27820
# Processing map 27830
# Processing map 27840
# Processing map 27850
# Processing map 27860
# Processing map 27870
# Processing map 27880
# Processing map 27890
# Processing map 27900
# Processing map 27910
# Processing map 27920
# Processing map 27930
# Processing map 27940
# Processing map 27950
# Processing map 27960
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 47
#      45     if map_idx % 10 == 0:
#      46         print(f"Processing map {map_idx}") # Print the current map index
# ---> 47     boundary = (watershed_by_flooding(graph, gradients_smoothed[:,map_idx])<0)*1 # Extract the bounary from the watershed algorithm
#      48     boundary_map += boundary
#      49 boundary_map_path = config["subjects_dir"] / f"boundary_smoothed_map_allsub_run{run}_{hemisphere}.npy"
#
# File c:\Users\Robin\Documents\1_EPFL\pdme\code\brain_parcellation\parcellation_surface\watershed.py, in watershed_by_flooding(graph, values)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# KeyboardInterrupt:
